# %% [markdown]
# # Exampe usage of asteroid class

# %%
import numpy as np
import scipy as sp
import pandas as pd
import scipy.optimize as opt
import random

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

#from asteroid import Asteroid
from asteroid_wspice import Asteroid

# %% [markdown]
# ## Example usage

# %%
# load data
df = pd.read_fwf('../gtoc4_problem_data.txt', sep='\t', skiprows=1)
df.columns =  ['Name','Epoch','a','e','i','LAN','omega','M0']
df.head()
# Out:
#      Name    Epoch         a         e          i         LAN       omega  \
# 0  '1580'  54800.0  2.196803  0.487683  52.090794   62.324795  159.539839
# 1  '1620'  54800.0  1.245551  0.335511  13.337693  337.266017  276.806539
# 2  '1943'  54800.0  1.430317  0.255816   8.704065  246.401915  338.253875
# 3  '2061'  54800.0  2.264953  0.537119   3.770822  207.654108  156.432028
# 4  '2135'  54800.0  1.599572  0.503268  23.054312  191.262849  290.838892
#
#            M0
# 0    3.521687
# 1  136.950031
# 2  288.405238
# 3   46.995497
# 4  256.724981

# %%
# load all asteroids into a list 
asteroids = [None,]*len(df)

# create asteroids
for i in range(len(df)):
    asteroids[i] = Asteroid(*tuple(df.loc[i].values))

# %%
asteroids
# Out:
# [Asteroid '1580',
#  Asteroid '1620',
#  Asteroid '1943',
#  Asteroid '2061',
#  Asteroid '2135',
#  Asteroid '2201',
#  Asteroid '2329',
#  Asteroid '2340',
#  Asteroid '2368',
#  Asteroid '3199',
#  Asteroid '3352',
#  Asteroid '3361',
#  Asteroid '3551',
#  Asteroid '3671',
#  Asteroid '3752',
#  Asteroid '3838',
#  Asteroid '4015',
#  Asteroid '4179',
#  Asteroid '4183',
#  Asteroid '4197',
#  Asteroid '4401',
#  Asteroid '4581',
#  Asteroid '4769',
#  Asteroid '4953',
#  Asteroid '4954',
#  Asteroid '5324',
#  Asteroid '5381',
#  Asteroid '5496',
#  Asteroid '5836',
#  Asteroid '5879',
#  Asteroid '6047',
#  Asteroid '6050',
#  Asteroid '6178',
#  Asteroid '6491',
#  Asteroid '6611',
#  Asteroid '7088',
#  Asteroid '7236',
#  Asteroid '7335',
#  Asteroid '7822',
#  Asteroid '7888',
#  Asteroid '7889',
#  Asteroid '7977',
#  Asteroid '8037',
#  Asteroid '8566',
#  Asteroid '10165',
#  Asteroid '11284',
#  Asteroid '15745',
#  Asteroid '15817',
#  Asteroid '18736',
#  Asteroid '20425',
#  Asteroid '20429',
#  Asteroid '22753',
#  Asteroid '24443',
#  Asteroid '25330',
#  Asteroid '26166',
#  Asteroid '26817',
#  Asteroid '29075',
#  Asteroid '31346',
#  Asteroid '40263',
#  Asteroid '52340',
#  Asteroid '52387',
#  Asteroid '52750',
#  Asteroid '53409',
#  Asteroid '54660',
#  Asteroid '54686',
#  Asteroid '55532',
#  Asteroid '65733',
#  Asteroid '67399',
#  Asteroid '68267',
#  Asteroid '68346',
#  Asteroid '68348',
#  Asteroid '68372',
#  Asteroid '85770',
#  Asteroid '85774',
#  Asteroid '85804',
#  Asteroid '85818',
#  Asteroid '85867',
#  Asteroid '85938',
#  Asteroid '86666',
#  Asteroid '86667',
#  Asteroid '86878',
#  Asteroid '87025',
#  Asteroid '88188',
#  Asteroid '88213',
#  Asteroid '88254',
#  Asteroid '88263',
#  Asteroid '89355',
#  Asteroid '89958',
#  Asteroid '90147',
#  Asteroid '90373',
#  Asteroid '96744',
#  Asteroid '99907',
#  Asteroid '101869',
#  Asteroid '108519',
#  Asteroid '115052',
#  Asteroid '136617',
#  Asteroid '136745',
#  Asteroid '136793',
#  Asteroid '136795',
#  Asteroid '136818',
#  Asteroid '136849',
#  Asteroid '136923',
#  Asteroid '137064',
#  Asteroid '137078',
#  Asteroid '137126',
#  Asteroid '137170',
#  Asteroid '137199',
#  Asteroid '137802',
#  Asteroid '137805',
#  Asteroid '138175',
#  Asteroid '138205',
#  Asteroid '138325',
#  Asteroid '138359',
#  Asteroid '138524',
#  Asteroid '138847',
#  Asteroid '138859',
#  Asteroid '138893',
#  Asteroid '138911',
#  Asteroid '138971',
#  Asteroid '139289',
#  Asteroid '140158',
#  Asteroid '140928',
#  Asteroid '141018',
#  Asteroid '141078',
#  Asteroid '141424',
#  Asteroid '141484',
#  Asteroid '141527',
#  Asteroid '141593',
#  Asteroid '141851',
#  Asteroid '142348',
#  Asteroid '142464',
#  Asteroid '143409',
#  Asteroid '143527',
#  Asteroid '143947',
#  Asteroid '144861',
#  Asteroid '145656',
#  Asteroid '152561',
#  Asteroid '152563',
#  Asteroid '152575',
#  Asteroid '152742',
#  Asteroid '152895',
#  Asteroid '153002',
#  Asteroid '153195',
#  Asteroid '153249',
#  Asteroid '153267',
#  Asteroid '153306',
#  Asteroid '153315',
#  Asteroid '153460',
#  Asteroid '153792',
#  Asteroid '154144',
#  Asteroid '154244',
#  Asteroid '154276',
#  Asteroid '154347',
#  Asteroid '154991',
#  Asteroid '155110',
#  Asteroid '159368',
#  Asteroid '159399',
#  Asteroid '159459',
#  Asteroid '159504',
#  Asteroid '159533',
#  Asteroid '159555',
#  Asteroid '161995',
#  Asteroid '162039',
#  Asteroid '162080',
#  Asteroid '162082',
#  Asteroid '162157',
#  Asteroid '162173',
#  Asteroid '162196',
#  Asteroid '162210',
#  Asteroid '162215',
#  Asteroid '162273',
#  Asteroid '162416',
#  Asteroid '162470',
#  Asteroid '162566',
#  Asteroid '162581',
#  Asteroid '162873',
#  Asteroid '162913',
#  Asteroid '162922',
#  Asteroid '162979',
#  Asteroid '162980',
#  Asteroid '163191',
#  Asteroid '163250',
#  Asteroid '163252',
#  Asteroid '163295',
#  Asteroid '163335',
#  Asteroid '163364',
#  Asteroid '163732',
#  Asteroid '164121',
#  Asteroid '164202',
#  Asteroid '164207',
#  Asteroid '164215',
#  Asteroid '164216',
#  Asteroid '164217',
#  Asteroid '164294',
#  Asteroid '164341',
#  Asteroid '164400',
#  Asteroid '170013',
#  Asteroid '172722',
#  Asteroid '173689',
#  Asteroid '174806',
#  Asteroid '175189',
#  Asteroid '175706',
#  Asteroid '175729',
#  Asteroid '177016',
#  Asteroid '177651',
#  Asteroid '185851',
#  Asteroid '186823',
#  Asteroid '186844',
#  Asteroid '189011',
#  Asteroid '189173',
#  Asteroid '189263',
#  Asteroid '190119',
#  Asteroid '190161',
#  Asteroid '190208',
#  Asteroid '190758',
#  Asteroid '190788',
#  Asteroid '191094',
#  Asteroid '192563',
#  Asteroid '194126',
#  Asteroid '194268',
#  Asteroid '196068',
#  Asteroid '199003',
#  Asteroid '199801',
#  Asteroid '1979XB',
#  Asteroid '1983LC',
#  Asteroid '1988NE',
#  Asteroid '1989AZ',
#  Asteroid '1990SM',
#  Asteroid '1991FB',
#  Asteroid '1991LH',
#  Asteroid '1991TT',
#  Asteroid '1991XB',
#  Asteroid '1992BC',
#  Asteroid '1993BU3,
#  Asteroid '1993FA1,
#  Asteroid '1993RA',
#  Asteroid '1993UD',
#  Asteroid '1993VC',
#  Asteroid '1993VD',
#  Asteroid '1994EK',
#  Asteroid '1994GV',
#  Asteroid '1994UG',
#  Asteroid '1994US',
#  Asteroid '1994WR1,
#  Asteroid '1995CR',
#  Asteroid '1995EK1,
#  Asteroid '1995FF',
#  Asteroid '1995FG',
#  Asteroid '1995SA4,
#  Asteroid '1995SB',
#  Asteroid '1996HN',
#  Asteroid '1996TE9,
#  Asteroid '1996XW1,
#  Asteroid '1996XX1,
#  Asteroid '1997CD1,
#  Asteroid '1997GL3,
#  Asteroid '1997MS',
#  Asteroid '1997QK1,
#  Asteroid '1997UA1,
#  Asteroid '1997UH9,
#  Asteroid '1997US2,
#  Asteroid '1997US9,
#  Asteroid '1997XR2,
#  Asteroid '1997XS2,
#  Asteroid '1998BT1,
#  Asteroid '1998BY7,
#  Asteroid '1998DK3,
#  Asteroid '1998FN9,
#  Asteroid '1998GC1,
#  Asteroid '1998HM3,
#  Asteroid '1998HN3,
#  Asteroid '1998KH9,
#  Asteroid '1998KJ1,
#  Asteroid '1998KM3,
#  Asteroid '1998MW5,
#  Asteroid '1998QA1,
#  Asteroid '1998QA1,
#  Asteroid '1998QQ',
#  Asteroid '1998QQ6,
#  Asteroid '1998SE3,
#  Asteroid '1998SL3,
#  Asteroid '1998ST4,
#  Asteroid '1998SV4,
#  Asteroid '1998UY2,
#  Asteroid '1998VD3,
#  Asteroid '1998WC2,
#  Asteroid '1998WP7,
#  Asteroid '1998XX2,
#  Asteroid '1998YF1,
#  Asteroid '1998YM4,
#  Asteroid '1999AF4,
#  Asteroid '1999AU2,
#  Asteroid '1999CW8,
#  Asteroid '1999ED5,
#  Asteroid '1999FP1,
#  Asteroid '1999GL4,
#  Asteroid '1999GR6,
#  Asteroid '1999GY5,
#  Asteroid '1999JU6,
#  Asteroid '1999LD3,
#  Asteroid '1999LP2,
#  Asteroid '1999LV7,
#  Asteroid '1999RK3,
#  Asteroid '1999TA1,
#  Asteroid '1999TC5,
#  Asteroid '1999TM1,
#  Asteroid '1999TN1,
#  Asteroid '1999TO1,
#  Asteroid '1999TT1,
#  Asteroid '1999TW1,
#  Asteroid '1999TX2,
#  Asteroid '1999VG2,
#  Asteroid '1999VM1,
#  Asteroid '1999VN6,
#  Asteroid '1999VR6,
#  Asteroid '1999VS6,
#  Asteroid '1999VV2,
#  Asteroid '1999VX1,
#  Asteroid '1999XM1,
#  Asteroid '1999YF3,
#  Asteroid '1999YR1,
#  Asteroid '2000AA6,
#  Asteroid '2000AD6,
#  Asteroid '2000AD2,
#  Asteroid '2000AE2,
#  Asteroid '2000AG6,
#  Asteroid '2000AG2,
#  Asteroid '2000BK1,
#  Asteroid '2000BL1,
#  Asteroid '2000BO2,
#  Asteroid '2000CR1,
#  Asteroid '2000DN1,
#  Asteroid '2000DV1,
#  Asteroid '2000EA1,
#  Asteroid '2000EB1,
#  Asteroid '2000EM2,
#  Asteroid '2000EU7,
#  Asteroid '2000EV1,
#  Asteroid '2000FP1,
#  Asteroid '2000GC1,
#  Asteroid '2000GF2,
#  Asteroid '2000GV1,
#  Asteroid '2000JB6,
#  Asteroid '2000LF3,
#  Asteroid '2000LG6,
#  Asteroid '2000OG8,
#  Asteroid '2000OH',
#  Asteroid '2000OK8,
#  Asteroid '2000PD3,
#  Asteroid '2000PG3,
#  Asteroid '2000PN',
#  Asteroid '2000PO3,
#  Asteroid '2000PP9,
#  Asteroid '2000QO1,
#  Asteroid '2000QU7,
#  Asteroid '2000QV7,
#  Asteroid '2000QW7,
#  Asteroid '2000QY6,
#  Asteroid '2000RD5,
#  Asteroid '2000RJ1,
#  Asteroid '2000RK1,
#  Asteroid '2000RK6,
#  Asteroid '2000RN7,
#  Asteroid '2000SB8,
#  Asteroid '2000SN1,
#  Asteroid '2000SS4,
#  Asteroid '2000SZ1,
#  Asteroid '2000TE2,
#  Asteroid '2000TG2,
#  Asteroid '2000TH1,
#  Asteroid '2000UG1,
#  Asteroid '2000WH1,
#  Asteroid '2000WM1,
#  Asteroid '2000WP1,
#  Asteroid '2000WP1,
#  Asteroid '2000WT2,
#  Asteroid '2000WY2,
#  Asteroid '2000YG2,
#  Asteroid '2000YJ2,
#  Asteroid '2001BA1,
#  Asteroid '2001BE1,
#  Asteroid '2001BN6,
#  Asteroid '2001BZ3,
#  Asteroid '2001DB3,
#  Asteroid '2001DC7,
#  Asteroid '2001DQ8,
#  Asteroid '2001DZ7,
#  Asteroid '2001EC1,
#  Asteroid '2001FA7,
#  Asteroid '2001FP3,
#  Asteroid '2001FX9,
#  Asteroid '2001GO2,
#  Asteroid '2001GQ2,
#  Asteroid '2001HA4,
#  Asteroid '2001HA8,
#  Asteroid '2001HC',
#  Asteroid '2001HX7,
#  Asteroid '2001HY7,
#  Asteroid '2001HZ7,
#  Asteroid '2001JW1,
#  Asteroid '2001KD6,
#  Asteroid '2001KW1,
#  Asteroid '2001LC',
#  Asteroid '2001LM5,
#  Asteroid '2001MR3,
#  Asteroid '2001OA1,
#  Asteroid '2001OD3,
#  Asteroid '2001OX1,
#  Asteroid '2001PD1,
#  Asteroid '2001QB3,
#  Asteroid '2001QD9,
#  Asteroid '2001QH1,
#  Asteroid '2001QM1,
#  Asteroid '2001QN1,
#  Asteroid '2001RA1,
#  Asteroid '2001RP3,
#  Asteroid '2001RQ1,
#  Asteroid '2001RX1,
#  Asteroid '2001RX4,
#  Asteroid '2001SA2,
#  Asteroid '2001SD3,
#  Asteroid '2001SE2,
#  Asteroid '2001SE2,
#  Asteroid '2001SG2,
#  Asteroid '2001SQ3,
#  Asteroid '2001SS2,
#  Asteroid '2001SY1,
#  Asteroid '2001TB',
#  Asteroid '2001TD',
#  Asteroid '2001TE4,
#  Asteroid '2001TY1,
#  Asteroid '2001TY4,
#  Asteroid '2001UC5,
#  Asteroid '2001UE1,
#  Asteroid '2001UF1,
#  Asteroid '2001UO',
#  Asteroid '2001UO2,
#  Asteroid '2001UQ1,
#  Asteroid '2001UW1,
#  Asteroid '2001UW1,
#  Asteroid '2001VB2,
#  Asteroid '2001VB7,
#  Asteroid '2001VC7,
#  Asteroid '2001VE7,
#  Asteroid '2001VF2,
#  Asteroid '2001VH5,
#  Asteroid '2001WH1,
#  Asteroid '2001WJ4,
#  Asteroid '2001WK1,
#  Asteroid '2001XE1,
#  Asteroid '2001XF1,
#  Asteroid '2001XG1,
#  Asteroid '2001XP8,
#  Asteroid '2001XQ3,
#  Asteroid '2001XV1,
#  Asteroid '2001XW1,
#  Asteroid '2001XW2,
#  Asteroid '2001XX1,
#  Asteroid '2001XY1,
#  Asteroid '2001YA1,
#  Asteroid '2001YE1,
#  Asteroid '2002AA',
#  Asteroid '2002AC2,
#  Asteroid '2002AF2,
#  Asteroid '2002AU4,
#  Asteroid '2002AV',
#  Asteroid '2002AW1,
#  Asteroid '2002AY1,
#  Asteroid '2002BJ2,
#  Asteroid '2002BK2,
#  Asteroid '2002BM2,
#  Asteroid '2002CS1,
#  Asteroid '2002CT4,
#  Asteroid '2002CT1,
#  Asteroid '2002CU4,
#  Asteroid '2002CW1,
#  Asteroid '2002CX5,
#  Asteroid '2002CY9,
#  Asteroid '2002CY5,
#  Asteroid '2002CZ5,
#  Asteroid '2002DJ5,
#  Asteroid '2002DQ3,
#  Asteroid '2002EB3,
#  Asteroid '2002EM7,
#  Asteroid '2002EV',
#  Asteroid '2002EY',
#  Asteroid '2002FB6,
#  Asteroid '2002FW1,
#  Asteroid '2002FW5,
#  Asteroid '2002GF8,
#  Asteroid '2002GK8,
#  Asteroid '2002GM2,
#  Asteroid '2002GR',
#  Asteroid '2002JA9,
#  Asteroid '2002JB9,
#  Asteroid '2002JE9,
#  Asteroid '2002JQ1,
#  Asteroid '2002JR9,
#  Asteroid '2002JR1,
#  Asteroid '2002KJ3,
#  Asteroid '2002KL3,
#  Asteroid '2002LZ4,
#  Asteroid '2002MT1,
#  Asteroid '2002NA3,
#  Asteroid '2002NW',
#  Asteroid '2002PE1,
#  Asteroid '2002PH8,
#  Asteroid '2002PO6,
#  Asteroid '2002QE7,
#  Asteroid '2002QH1,
#  Asteroid '2002QQ4,
#  Asteroid '2002RC1,
#  Asteroid '2002RH5,
#  Asteroid '2002RP2,
#  Asteroid '2002RT1,
#  Asteroid '2002RV1,
#  Asteroid '2002SL',
#  Asteroid '2002SN',
#  Asteroid '2002SQ4,
#  Asteroid '2002SR',
#  Asteroid '2002SV',
#  Asteroid '2002TS6,
#  Asteroid '2002TX5,
#  Asteroid '2002TX5,
#  Asteroid '2002TY6,
#  Asteroid '2002UL1,
#  Asteroid '2002UN3,
#  Asteroid '2002UX',
#  Asteroid '2002VD1,
#  Asteroid '2002VE6,
#  Asteroid '2002VO6,
#  Asteroid '2002VQ1,
#  Asteroid '2002VR1,
#  Asteroid '2002VV1,
#  Asteroid '2002VX9,
#  Asteroid '2002VY9,
#  Asteroid '2002WP',
#  Asteroid '2002WX1,
#  Asteroid '2002XA',
#  Asteroid '2002XA4,
#  Asteroid '2002XB4,
#  Asteroid '2002XM9,
#  Asteroid '2002XN1,
#  Asteroid '2002XT4,
#  Asteroid '2002XT9,
#  Asteroid '2002XV9,
#  Asteroid '2002XX4,
#  Asteroid '2002XY3,
#  Asteroid '2002YD1,
#  Asteroid '2002YO2,
#  Asteroid '2002YQ5,
#  Asteroid '2003AA3,
#  Asteroid '2003AA8,
#  Asteroid '2003AF2,
#  Asteroid '2003AO4,
#  Asteroid '2003AS4,
#  Asteroid '2003AY2,
#  Asteroid '2003BA2,
#  Asteroid '2003BB2,
#  Asteroid '2003BK4,
#  Asteroid '2003BN4,
#  Asteroid '2003BO1,
#  Asteroid '2003BS4,
#  Asteroid '2003BX3,
#  Asteroid '2003CA',
#  Asteroid '2003CR1,
#  Asteroid '2003DE6,
#  Asteroid '2003DF6,
#  Asteroid '2003DN4,
#  Asteroid '2003DW1,
#  Asteroid '2003DX1,
#  Asteroid '2003DZ1,
#  Asteroid '2003ED5,
#  Asteroid '2003EG1,
#  Asteroid '2003EJ5,
#  Asteroid '2003EZ1,
#  Asteroid '2003FB5,
#  Asteroid '2003FF5,
#  Asteroid '2003FJ1,
#  Asteroid '2003FQ6,
#  Asteroid '2003FT3,
#  Asteroid '2003FU3,
#  Asteroid '2003GD',
#  Asteroid '2003GD4,
#  Asteroid '2003GP5,
#  Asteroid '2003GS2,
#  Asteroid '2003GX',
#  Asteroid '2003HB6,
#  Asteroid '2003HF2,
#  Asteroid '2003HP3,
#  Asteroid '2003HR3,
#  Asteroid '2003HW1,
#  Asteroid '2003JD1,
#  Asteroid '2003JD1,
#  Asteroid '2003JO1,
#  Asteroid '2003JV1,
#  Asteroid '2003KU2,
#  Asteroid '2003KX1,
#  Asteroid '2003LH',
#  Asteroid '2003LN6,
#  Asteroid '2003LS3,
#  Asteroid '2003LW2,
#  Asteroid '2003MD7,
#  Asteroid '2003ME1,
#  Asteroid '2003MH4,
#  Asteroid '2003MT2,
#  Asteroid '2003MT9,
#  Asteroid '2003ND',
#  Asteroid '2003NO4,
#  Asteroid '2003OQ1,
#  Asteroid '2003OT1,
#  Asteroid '2003QC',
#  Asteroid '2003QW3,
#  Asteroid '2003QY2,
#  Asteroid '2003QZ2,
#  Asteroid '2003RD5,
#  Asteroid '2003SF',
#  Asteroid '2003SG1,
#  Asteroid '2003SH8,
#  Asteroid '2003SJ8,
#  Asteroid '2003SK2,
#  Asteroid '2003SM2,
#  Asteroid '2003SN2,
#  Asteroid '2003SQ1,
#  Asteroid '2003SR8,
#  Asteroid '2003SU8,
#  Asteroid '2003SV1,
#  Asteroid '2003SW1,
#  Asteroid '2003SY4,
#  Asteroid '2003TH2,
#  Asteroid '2003TK2,
#  Asteroid '2003TM1,
#  Asteroid '2003TN1,
#  Asteroid '2003UB2,
#  Asteroid '2003UC5,
#  Asteroid '2003UC2,
#  Asteroid '2003UE2,
#  Asteroid '2003UO2,
#  Asteroid '2003UP1,
#  Asteroid '2003UP2,
#  Asteroid '2003UQ2,
#  Asteroid '2003UR1,
#  Asteroid '2003UX2,
#  Asteroid '2003UX3,
#  Asteroid '2003VE1,
#  Asteroid '2003VG1,
#  Asteroid '2003WB2,
#  Asteroid '2003WE1,
#  Asteroid '2003WL2,
#  Asteroid '2003WO1,
#  Asteroid '2003WP7,
#  Asteroid '2003WP2,
#  Asteroid '2003WR2,
#  Asteroid '2003WU2,
#  Asteroid '2003WX2,
#  Asteroid '2003WY1,
#  Asteroid '2003XJ7,
#  Asteroid '2003XK',
#  Asteroid '2003YD4,
#  Asteroid '2003YG1,
#  Asteroid '2003YG1,
#  Asteroid '2003YH1,
#  Asteroid '2003YH1,
#  Asteroid '2003YL',
#  Asteroid '2003YM1,
#  Asteroid '2003YO1,
#  Asteroid '2003YP3,
#  Asteroid '2003YP9,
#  Asteroid '2003YQ9,
#  Asteroid '2003YT7,
#  Asteroid '2003YT1,
#  Asteroid '2003YW1,
#  Asteroid '2004BB1,
#  Asteroid '2004BF1,
#  Asteroid '2004BG4,
#  Asteroid '2004BG1,
#  Asteroid '2004BH1,
#  Asteroid '2004BH4,
#  Asteroid '2004BJ1,
#  Asteroid '2004BK1,
#  Asteroid '2004BN4,
#  Asteroid '2004BW1,
#  Asteroid '2004BY2,
#  Asteroid '2004BZ7,
#  Asteroid '2004CE3,
#  Asteroid '2004CO4,
#  Asteroid '2004CZ1,
#  Asteroid '2004DH2,
#  Asteroid '2004EK1,
#  Asteroid '2004EN2,
#  Asteroid '2004FA',
#  Asteroid '2004FD',
#  Asteroid '2004FE4,
#  Asteroid '2004FG1,
#  Asteroid '2004FP4,
#  Asteroid '2004FU6,
#  Asteroid '2004FW1,
#  Asteroid '2004FZ1,
#  Asteroid '2004GD',
#  Asteroid '2004GD2,
#  Asteroid '2004HC',
#  Asteroid '2004HD2,
#  Asteroid '2004HE',
#  Asteroid '2004HO1,
#  Asteroid '2004HT5,
#  Asteroid '2004HW5,
#  Asteroid '2004JA',
#  Asteroid '2004JB1,
#  Asteroid '2004JG6,
#  Asteroid '2004JN1,
#  Asteroid '2004JN2,
#  Asteroid '2004JO2,
#  Asteroid '2004JP1,
#  Asteroid '2004JW2,
#  Asteroid '2004KZ',
#  Asteroid '2004KZ1,
#  Asteroid '2004LC2,
#  Asteroid '2004LK',
#  Asteroid '2004LX5,
#  Asteroid '2004MC',
#  Asteroid '2004ME6,
#  Asteroid '2004MP7,
#  Asteroid '2004MQ1,
#  Asteroid '2004MS1,
#  Asteroid '2004MW2,
#  Asteroid '2004NC9,
#  Asteroid '2004NF3,
#  Asteroid '2004NK8,
#  Asteroid '2004NL8,
#  Asteroid '2004OF6,
#  Asteroid '2004PB9,
#  Asteroid '2004PJ2,
#  Asteroid '2004PR9,
#  Asteroid '2004QD2,
#  Asteroid '2004QG2,
#  Asteroid '2004QJ1,
#  Asteroid '2004QX2,
#  Asteroid '2004RB1,
#  Asteroid '2004RC1,
#  Asteroid '2004RC2,
#  Asteroid '2004RD8,
#  Asteroid '2004RK',
#  Asteroid '2004RK9,
#  Asteroid '2004RN1,
#  Asteroid '2004RQ1,
#  Asteroid '2004RQ2,
#  Asteroid '2004RS1,
#  Asteroid '2004RU1,
#  Asteroid '2004RU1,
#  Asteroid '2004RU3,
#  Asteroid '2004RY1,
#  Asteroid '2004SA',
#  Asteroid '2004SA1,
#  Asteroid '2004SA2,
#  Asteroid '2004SB2,
#  Asteroid '2004SB5,
#  Asteroid '2004SD2,
#  Asteroid '2004SD2,
#  Asteroid '2004SS',
#  Asteroid '2004ST9,
#  Asteroid '2004TB1,
#  Asteroid '2004TK1,
#  Asteroid '2004TL1,
#  Asteroid '2004TL1,
#  Asteroid '2004TN',
#  Asteroid '2004TN1,
#  Asteroid '2004TO2,
#  Asteroid '2004TP1,
#  Asteroid '2004TP2,
#  Asteroid '2004TR1,
#  Asteroid '2004TT1,
#  Asteroid '2004UL',
#  Asteroid '2004UT1,
#  Asteroid '2004UU1,
#  Asteroid '2004VA1,
#  Asteroid '2004VB6,
#  Asteroid '2004VH1,
#  Asteroid '2004VP',
#  Asteroid '2004XB4,
#  Asteroid '2004XD6,
#  Asteroid '2004XD5,
#  Asteroid '2004XG',
#  Asteroid '2004XH2,
#  Asteroid '2004XJ3,
#  Asteroid '2004XK3,
#  Asteroid '2004XM1,
#  Asteroid '2004XN2,
#  Asteroid '2004XN4,
#  Asteroid '2004XY6,
#  Asteroid '2004YC',
#  Asteroid '2004YG1,
#  Asteroid '2004YZ2,
#  Asteroid '2005AD3,
#  Asteroid '2005AU3,
#  Asteroid '2005BC',
#  Asteroid '2005BE',
#  Asteroid '2005BG1,
#  Asteroid '2005BG2,
#  Asteroid '2005BN1,
#  Asteroid '2005CA7,
#  Asteroid '2005CD6,
#  Asteroid '2005CF4,
#  Asteroid '2005CN',
#  Asteroid '2005CS6,
#  Asteroid '2005CW2,
#  Asteroid '2005EB3,
#  Asteroid '2005ED3,
#  Asteroid '2005EH9,
#  Asteroid '2005EL7,
#  Asteroid '2005EN7,
#  Asteroid '2005EO3,
#  Asteroid '2005EQ7,
#  Asteroid '2005ES1,
#  Asteroid '2005ET7,
#  Asteroid '2005ET9,
#  Asteroid '2005EU2,
#  Asteroid '2005EY1,
#  Asteroid '2005EZ',
#  Asteroid '2005EZ1,
#  Asteroid '2005FH',
#  Asteroid '2005FN',
#  Asteroid '2005GA1,
#  Asteroid '2005GC1,
#  Asteroid '2005GC1,
#  Asteroid '2005GE5,
#  Asteroid '2005GG',
#  Asteroid '2005GH',
#  Asteroid '2005GJ8,
#  Asteroid '2005GL1,
#  Asteroid '2005GM1,
#  Asteroid '2005GQ3,
#  Asteroid '2005GU',
#  Asteroid '2005GW1,
#  Asteroid '2005GY8,
#  Asteroid '2005HB',
#  Asteroid '2005HB4,
#  Asteroid '2005HD4,
#  Asteroid '2005HM3,
#  Asteroid '2005JD4,
#  Asteroid '2005JE4,
#  Asteroid '2005JF4,
#  Asteroid '2005JF1,
#  Asteroid '2005JJ9,
#  Asteroid '2005JN3,
#  Asteroid '2005JR5,
#  Asteroid '2005JU1,
#  Asteroid '2005JU1,
#  Asteroid '2005JV1,
#  Asteroid '2005KD7,
#  Asteroid '2005KR',
#  Asteroid '2005LP4,
#  Asteroid '2005LU3,
#  Asteroid '2005LV3,
#  Asteroid '2005LY1,
#  Asteroid '2005MC',
#  Asteroid '2005MG5,
#  Asteroid '2005ML1,
#  Asteroid '2005MO1,
#  Asteroid '2005MP1,
#  Asteroid '2005MW9,
#  Asteroid '2005NE2,
#  Asteroid '2005NG',
#  Asteroid '2005NG5,
#  Asteroid '2005NJ6,
#  Asteroid '2005NW4,
#  Asteroid '2005NX4,
#  Asteroid '2005NX5,
#  Asteroid '2005NZ6,
#  Asteroid '2005OF3,
#  Asteroid '2005OJ3,
#  Asteroid '2005OU2,
#  Asteroid '2005OW',
#  Asteroid '2005PO',
#  Asteroid '2005PY1,
#  Asteroid '2005QB5,
#  Asteroid '2005QQ3,
#  Asteroid '2005QR8,
#  Asteroid '2005QX1,
#  Asteroid '2005RC',
#  Asteroid '2005RD3,
#  Asteroid '2005RN3,
#  Asteroid '2005RR6,
#  Asteroid '2005SC',
#  Asteroid '2005SG2,
#  Asteroid '2005SH1,
#  Asteroid '2005SN2,
#  Asteroid '2005SO1,
#  Asteroid '2005SP1,
#  Asteroid '2005SR1,
#  Asteroid '2005SS4,
#  Asteroid '2005SV4,
#  Asteroid '2005SX4,
#  Asteroid '2005SY7,
#  Asteroid '2005TC',
#  Asteroid '2005TD4,
#  Asteroid '2005TE',
#  Asteroid '2005TF4,
#  Asteroid '2005TF4,
#  Asteroid '2005TM',
#  Asteroid '2005TN',
#  Asteroid '2005TP',
#  Asteroid '2005TR1,
#  Asteroid '2005TU4,
#  Asteroid '2005UB',
#  Asteroid '2005UF',
#  Asteroid '2005UF1,
#  Asteroid '2005UH',
#  Asteroid '2005UH6,
#  Asteroid '2005UL1,
#  Asteroid '2005UN1,
#  Asteroid '2005UP6,
#  Asteroid '2005UQ',
#  Asteroid '2005UT6,
#  Asteroid '2005UU6,
#  Asteroid '2005UW5,
#  Asteroid '2005UY5,
#  Asteroid '2005VB7,
#  Asteroid '2005VE',
#  Asteroid '2005VJ1,
#  Asteroid '2005VO',
#  Asteroid '2005VR7,
#  Asteroid '2005VT2,
#  Asteroid '2005VY1,
#  Asteroid '2005WE5,
#  Asteroid '2005WF4,
#  Asteroid '2005WG4,
#  Asteroid '2005WK4,
#  Asteroid '2005WM3,
#  Asteroid '2005WO3,
#  Asteroid '2005WR2,
#  Asteroid '2005WR3,
#  Asteroid '2005WS3,
#  Asteroid '2005XA',
#  Asteroid '2005XC1,
#  Asteroid '2005XL8,
#  Asteroid '2005XM4,
#  Asteroid '2005XN',
#  Asteroid '2005XN2,
#  Asteroid '2005XP6,
#  Asteroid '2005XW7,
#  Asteroid '2005XY4,
#  Asteroid '2005YC',
#  Asteroid '2005YK',
#  Asteroid '2005YN1,
#  Asteroid '2005YP5,
#  Asteroid '2005YP1,
#  Asteroid '2005YT5,
#  Asteroid '2005YT1,
#  Asteroid '2005YU8,
#  Asteroid '2005YY3,
#  Asteroid '2006AC3,
#  Asteroid '2006AD',
#  Asteroid '2006AH4,
#  Asteroid '2006AL4,
#  Asteroid '2006AN',
#  Asteroid '2006AO4,
#  Asteroid '2006AP3,
#  Asteroid '2006AT2,
#  Asteroid '2006AU3,
#  Asteroid '2006AX',
#  Asteroid '2006BB9,
#  Asteroid '2006BC8,
#  Asteroid '2006BE5,
#  Asteroid '2006BG',
#  Asteroid '2006BO7,
#  Asteroid '2006BP1,
#  Asteroid '2006BT7,
#  Asteroid '2006BX1,
#  Asteroid '2006BY7,
#  Asteroid '2006BY8,
#  Asteroid '2006BZ1,
#  Asteroid '2006CL',
#  Asteroid '2006CN1,
#  Asteroid '2006CT1,
#  Asteroid '2006CU1,
#  Asteroid '2006CV9,
#  Asteroid '2006CW',
#  Asteroid '2006CX',
#  Asteroid '2006CX1,
#  Asteroid '2006DM',
#  Asteroid '2006DN',
#  Asteroid '2006DP1,
#  Asteroid '2006DQ6,
#  Asteroid '2006DS6,
#  Asteroid '2006DT1,
#  Asteroid '2006DT6,
#  Asteroid '2006EA',
#  Asteroid '2006EC',
#  Asteroid '2006EF1,
#  Asteroid '2006FJ',
#  Asteroid '2006FJ9,
#  Asteroid '2006FX',
#  Asteroid '2006FY3,
#  Asteroid '2006GA',
#  Asteroid '2006GB',
#  Asteroid '2006GC1,
#  Asteroid '2006GQ2,
#  Asteroid '2006GT3,
#  Asteroid '2006GU',
#  Asteroid '2006HA6,
#  ...]

# %%
#printing
print(asteroids[0])
# Out:
# Asteroid '1580'

# %%
print(asteroids[0].details())
# Out:
# *Asteroid '1580'*
#   Epoch0 (MJD)  : 54800.0
#   a (AU)        : 2.1968033753931695
#   e_mag         : 0.4876831067819973
#   i (deg)       : 52.09079390385544
#   LAN (deg)     : 62.324795115974354
#   argPeri (deg) : 159.53983855505257
#   meanAnom (deg): 3.5216868177911254

# %%
# define epochs in MJD
epoch = 54801
# for simplicity
ast1 = asteroids[1]
ast2 = asteroids[2]

# %%
# you can get the position
ast1.get_r(epoch = 54810)
# Out:
# array([1.75465817e+08, 1.37572392e+08, 4.61588739e+07])

# %%
# or the distance from the sun (in km)
ast2.get_r_mag(epoch = epoch)
# Out:
# 168928374.4577587

# %%
# or other parameters
# all angles are in radians
print(f'mean anom: {ast1.get_meanAnom(epoch)}')
print(f'ecc  anom: {ast1.get_eccAnom(epoch)}')
print(f'true anom: {ast1.get_trueAnom(epoch)}')
# Out:
# mean anom: 2.4026037891137104
# ecc  anom: 2.580992889460019
# true anom: 2.3276532212459236

# %%
# you can also use a different method, if you provide the necessary details
ast1.get_trueAnom(epoch, method='secant', x0=5, x1=10)
# Out:
# 2.3276532212459236

# %%
print(f'Get state-vector using gtoc definition: \n{ast1.get_rv(epoch=epoch)}')
print(f'Get state-vector using SPICE definition: \n{ast1.get_rv_spice(epoch=epoch)}')
# Out:
# Get state-vector using gtoc definition:
# (array([1.88966199e+08, 9.48949509e+07, 3.80637286e+07]), array([-4.11455998, 22.05544359,  4.44577732]))
# Get state-vector using SPICE definition:
# (array([1.90841288e+08, 3.89161613e+07, 2.59949046e+07]), array([ 2.87150351, 24.4702404 ,  5.61388788]))

# %%
# compute vector to get from one asteroid to another
# returns (ast_2.r - ast_1.r)
ast1.dist_to(ast2, epoch)
# Out:
# array([-1.93355199e+08, -2.63486527e+08, -2.83471006e+07])

# %%
# compute distance (magnitude) between two asteroids
# returns norm(ast_2.r - ast_1.r)
ast1.dist_to_mag(ast2, epoch)
# Out:
# 328047162.6179346

# %%
# create a list of distanes from 0th asteroid to all other asteroids, and print the minimum
dists = [(asteroids[i].name, asteroids[0].dist_to_mag(asteroids[i],epoch)) for i in range(len(asteroids)) if i is not 0]
ast, dist = min(dists, key = lambda t: t[1])
print(f'Closest to {ast}, dist = {dist} km')
# Out:
# Closest to Asteroid '2000BL1, dist = 17850601.63149388 km

# %%
# same for a range of times
times = np.linspace(54800, 55100, 11)
AU = 1.29597870691e+8

for epoch in times:
    dists = [(asteroids[i].name, asteroids[0].dist_to_mag(asteroids[i],epoch)) for i in range(len(asteroids)) if i is not 0]
    ast, dist = min(dists, key = lambda t: t[1])
    print(f'Epoch {epoch}: Closest to {ast}; dist = {dist/AU} AU')
# Out:
# Epoch 54800.0: Closest to Asteroid '2000BL1; dist = 0.11952287287596905 AU
# Epoch 54830.0: Closest to Asteroid '1999LV7; dist = 0.9042974160965085 AU
# Epoch 54860.0: Closest to Asteroid '2007HD7; dist = 0.24604357582440728 AU
# Epoch 54890.0: Closest to Asteroid '2006CX1; dist = 0.7550781501425771 AU
# Epoch 54920.0: Closest to Asteroid '2006JT'; dist = 0.6603503509787737 AU
# Epoch 54950.0: Closest to Asteroid '7822'; dist = 0.34230174872318814 AU
# Epoch 54980.0: Closest to Asteroid '2008CP'; dist = 0.07725096536016754 AU
# Epoch 55010.0: Closest to Asteroid '2007DS8; dist = 0.0872647472455877 AU
# Epoch 55040.0: Closest to Asteroid '2002GK8; dist = 0.23287192123650227 AU
# Epoch 55070.0: Closest to Asteroid '2004FU6; dist = 0.4112877627888063 AU
# Epoch 55100.0: Closest to Asteroid '2006KS3; dist = 0.8041837411145197 AU

# %%
# image of distances between asteroids, at a given epoch
N = len(asteroids)

dists = np.zeros([N,N])
AU = 1.29597870691e+8
epoch = 54800

for i in range(N):
    for j in range(N):
        if j>i:
            d = asteroids[i].dist_to_mag(asteroids[j], epoch)/AU
            dists[i,j] = d
            dists[j,i] = d
            
# pretty efficient because the positions from the last epoch that we calculated are stored 
# within the object and can be quickly retrived. Means the positions are only calculated once for each asteroid
# the gridded distance calcs need to be done on the upper-triangular space, and takes a few seconds on python

# %%
plt.imshow(dists)
plt.colorbar()
plt.title(f'Distance (AU) between asteroids at {epoch}MJD')
# Out:
# Text(0.5, 1.0, 'Distance (AU) between asteroids at 54800MJD')

# %%
# therefore we can see that the minimum distance between two asteroids at epoch is about 0.005 AU
dists[dists>0].min()
# Out:
# 0.004284454739699919

# %%
# %%timeit

# image of distances between asteroids, at a given epoch
N = len(asteroids)

dists = np.zeros([N,N])
AU = 1.29597870691e+8
epoch = random.randint(54800, 55900)

for i in range(N):
    for j in range(N):
        if j>i:
            d = asteroids[i].dist_to_mag(asteroids[j], epoch)/AU
            dists[i,j] = d
            dists[j,i] = d
            
# pretty efficient because the positions from the last epoch that we calculated are stored 
# within the object and can be quickly retrived. Means the positions are only calculated once for each asteroid
# the gridded distance calcs need to be done on the upper-triangular space, and takes a few seconds on python
plt.figure()
plt.imshow(dists)
plt.colorbar()
plt.title(f'Distance (AU) between asteroids at {epoch}MJD')

# therefore we can see that the minimum distance between two asteroids at epoch is about 0.005 AU
print(f'for {epoch}MJD: min_dist is {dists[dists>0].min()} AU')
# Out:
# for 54941MJD: min_dist is 0.02413932858615505 AU
# for 55740MJD: min_dist is 0.013179437971599898 AU
# for 55306MJD: min_dist is 0.013870745746790793 AU
# for 55218MJD: min_dist is 0.010031328894886043 AU
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-addca8794bc2> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "\n# image of distances between asteroids, at a given epoch\nN = len(asteroids)\n\ndists = np.zeros([N,N])\nAU = 1.29597870691e+8\nepoch = random.randint(54800, 55900)\n\nfor i in range(N):\n    for j in range(N):\n        if j>i:\n            d = asteroids[i].dist_to_mag(asteroids[j], epoch)/AU\n            dists[i,j] = d\n            dists[j,i] = d\n            \n# pretty efficient because the positions from the last epoch that we calculated are stored \n# within the object and can be quickly retrived. Means the positions are only calculated once for each asteroid\n# the gridded distance calcs need to be done on the upper-triangular space, and takes a few seconds on python\nplt.figure()\nplt.imshow(dists)\nplt.colorbar()\nplt.title(f'Distance (AU) between asteroids at {epoch}MJD')\n\n# therefore we can see that the minimum distance between two asteroids at epoch is about 0.005 AU\nprint(f'for {epoch}MJD: min_dist is {dists[dists>0].min()} AU')\n")
#
# ~\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2350             with self.builtin_trap:
#    2351                 args = (magic_arg_s, cell)
# -> 2352                 result = fn(*args, **kwargs)
#    2353             return result
#    2354
#
# <C:\Users\yurio\Anaconda3\lib\site-packages\decorator.py:decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# ~\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell, local_ns)
#    1149                     break
#    1150
# -> 1151         all_runs = timer.repeat(repeat, number)
#    1152         best = min(all_runs) / number
#    1153         worst = max(all_runs) / number
#
# ~\Anaconda3\lib\timeit.py in repeat(self, repeat, number)
#     202         r = []
#     203         for i in range(repeat):
# --> 204             t = self.timeit(number)
#     205             r.append(t)
#     206         return r
#
# ~\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     159         gc.disable()
#     160         try:
# --> 161             timing = self.inner(it, self.timer)
#     162         finally:
#     163             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# ~\Documents\GitHub\reGTOC04\jupyternotebooks\asteroid_wspice.py in dist_to_mag(self, other, epoch, **kwargs)
#     348         dr = self.dist_to(other, epoch, **kwargs)
#     349
# --> 350         return np.linalg.norm(dr)
#     351
#     352
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2448                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2449             else:
# -> 2450                 sqnorm = dot(x, x)
#    2451             ret = sqrt(sqnorm)
#    2452             if keepdims:
#
# KeyboardInterrupt:

# %%
etrange = np.linspace(54801, 54901, 100)
r = []

# for # of asteroids
for el in etrange:
    r.append(ast1.get_r_mag(el))
